# %%
print("이 수업은 기계학습입니다.", end='')
# Out:
# 이 수업은 기계학습입니다.

# %%
class Person:

    name: str
    age: int
    univ: str
    major: str
    student_id: str

    def __init__(self, **kwargs) -> None:
        if not kwargs or len(kwargs) != 5:
            raise ValueError(f"Person 클래스는 5개의 인자를 받아야 합니다.")

        for key, value in kwargs.items():
            setattr(self, key, value)

# %%
data_minsu = {
    "name": "김민수",
    "age": 27,
    "univ": "조선대학교",
    "major": "인공지능공학과",
    "student_id": "20244792"
}

# %%
minsu = Person(**data_minsu)

for k, v in minsu.__dict__.items():
    print(f"{k}: {v}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 minsu = Person(**data_minsu)
#       3 for k, v in minsu.__dict__.items():
#       4     print(f"{k}: {v}")
#
# Cell In[5], line 15, in Person.__init__(self, **kwargs)
#      13 for key, value in kwargs.items():
#      14     if key not in self.__dict__:
# ---> 15         raise ValueError(f"Person 클래스는 {key} 속성을 가지고 있지 않습니다.")
#      16     setattr(self, key, value)
#
# ValueError: Person 클래스는 name 속성을 가지고 있지 않습니다.
